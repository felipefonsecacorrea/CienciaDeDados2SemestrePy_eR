# %%
#Crie um sistema simples de gerenciamento de contatos que permita adicionar novos contatos,
#remover contatos e listar todos os contatos com seus detalhes.
#O sistema deve utilizar variáveis e operações diretamente, sem a utilização de funções.
contatos <- list(
    "contato1" <- list(nome ="felipe", celular= "916685029",email= "felipe@email.com"),
    "contato2" <- list(nome= "ana",celular= "989328222",email= "ana@email.com"),
    "contato3" <- list(nome= "aline",celular="40028922",email= "calote@email.com")
)

print(contatos)

print("/////////////////////////////////////////////")

#adicione mais uma pessoa no contatos
contatos[["contato4"]] <- list(nome="vitor",celular="40028922",email= "lindo@email.com")

print(contatos["contato4"])

print("/////////////////////////////////////////////")

#remova uma pessoa do contatos
contatos[3] <- NULL

print(contatos)

print("/////////////////////////////////////////////")

for (i in contatos){
    print(paste("Nome:", i$nome, ", Celular:", i$celular, ", Email:", i$email))
}
print("*** Fim da lista ***")
# Out:
# [[1]]
# [[1]]$nome
# [1] "felipe"
#
# [[1]]$celular
# [1] "916685029"
#
# [[1]]$email
# [1] "felipe@email.com"
#
#
# [[2]]
# [[2]]$nome
# [1] "ana"
#
# [[2]]$celular
# [1] "989328222"
#
# [[2]]$email
# [1] "ana@email.com"
#
#
# [[3]]
# [[3]]$nome
# [1] "aline"
#
# [[3]]$celular
# [1] "40028922"
#
# [[3]]$email
# [1] "calote@email.com"
#
#
# [1] "/////////////////////////////////////////////"
# $contato4
# $contato4$nome
# [1] "vitor"
#
# $contato4$celular
# [1] "40028922"
#
# $contato4$email
# [1] "lindo@email.com"
#
#
# [1] "/////////////////////////////////////////////"
# [[1]]
# [[1]]$nome
# [1] "felipe"
#
# [[1]]$celular
# [1] "916685029"
#
# [[1]]$email
# [1] "felipe@email.com"
#
#
# [[2]]
# [[2]]$nome
# [1] "ana"
#
# [[2]]$celular
# [1] "989328222"
#
# [[2]]$email
# [1] "ana@email.com"
#
#
# $contato4
# $contato4$nome
# [1] "vitor"
#
# $contato4$celular
# [1] "40028922"
#
# $contato4$email
# [1] "lindo@email.com"
#
#
# [1] "/////////////////////////////////////////////"
# ...
